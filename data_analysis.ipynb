# %%
import pandas as pd 
import matplotlib.pyplot as plt
# Imports the modules for data analysis and plotting.
constant_beta_1d = pd.read_csv('constant_beta_1D.csv')
# Reads the csv in as a dataframe to be explored in python.
plt.figure()

plt.subplot(1, 2, 1)
plt.hist(constant_beta_1d['magnetization'], bins=30)
plt.title('Magnetization Distribution at beta = 1.0')
plt.xlabel('Magnetization')
plt.ylabel('Frequency') 
# This sets up the plot and as this first plot
# is showing distribution, a histogram is used. It is shown as a subplot, so 
# the distribution of magnetisation can be directly compared to the energy
# distribution. Have also labelled the axis.

plt.subplot(1, 2, 2)
plt.hist(constant_beta_1d['energy'], bins=30, color='red')
plt.title('Energy Distribution (beta = 1.0)')
plt.xlabel('Energy')
plt.ylabel('Frequency')

plt.show() 

# Very similarly here, the energy distribution histogram is set up alongside the
# magnetisation one and the axis are plotted and shown.

vary_beta_1d = pd.read_csv("1d_vary_beta.csv") 
# Once again this data for the different energies and magnetizations as different
# beta values in the chain of atoms is read into a pandas dataframe and plotted.

plt.figure()
plt.scatter(vary_beta_1d['beta'], vary_beta_1d['avg_magnetization'])
plt.title('1D Ising Model: Beta vs Magnetization')
plt.xlabel('Beta (inverse temperature)')
plt.ylabel('Average Magnetization')
plt.grid(True)
plt.show()
# A scatter plot was chosen here as it best demonstrates the general trend of how
# magnetisation changes at different beta values. 

vary_beta_2d = pd.read_csv("2d_vary_beta.csv")

plt.figure()
plt.plot(vary_beta_2d['beta'], vary_beta_2d['magnetization'])
plt.title('2D Model: Beta vs Magnetization')
plt.xlabel('Beta (inverse temperature)')
plt.ylabel('Average Magnetization')
plt.grid(True)
# This is the final plot, again of magnetisation at different beta values. This is little
# clear correlation in this plot, so a line graph was chosen just for clarity, though a scatter
# would work similarly well. It is labelled with a title and axis and both plots have a grid
# background too for aesthetic purposes.

plt.show()
