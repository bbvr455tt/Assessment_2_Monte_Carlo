# %%
import pandas as pd
data = pd.read_csv("constant_beta_1D.csv")
data
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
