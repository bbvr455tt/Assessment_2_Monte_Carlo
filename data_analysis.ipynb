# %%
import pandas as pd 
import matplotlib.pyplot as plt

constant_beta_1d = pd.read_csv('constant_beta_1D.csv')

plt.figure()

plt.subplot(1, 2, 1)
plt.hist(constant_beta_1d['magnetization'], bins=30)
plt.title('Magnetization Distribution (beta = 1.0)')
plt.xlabel('Magnetization')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
plt.hist(constant_beta_1d['energy'], bins=30, color='red')
plt.title('Energy Distribution (beta = 1.0)')
plt.xlabel('Energy')
plt.ylabel('Frequency')

plt.show()

vary_beta_1d = pd.read_csv("1d_vary_beta.csv")

plt.figure()
plt.scatter(vary_beta_1d['beta'], vary_beta_1d['avg_magnetization'])
plt.title('1D Ising Model: Beta vs Magnetization')
plt.xlabel('Inverse Temperature (beta)')
plt.ylabel('Average Magnetization')
plt.grid(True)
plt.show()

vary_beta_2d = pd.read_csv("2d_vary_beta.csv")

plt.figure()
plt.plot(vary_beta_2d['beta'], vary_beta_2d['magnetization'])
plt.title('2D Model: Beta vs Magnetization')
plt.xlabel('Inverse Temperature (beta)')
plt.ylabel('Average Magnetization')
plt.grid(True)


plt.show()
